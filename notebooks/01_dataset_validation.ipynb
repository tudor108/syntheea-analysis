# %% [markdown]
# # Dataset validation
# **SYNTHETIC DEMO DATA – NOT REAL BAYER OR CLINICAL DATA**

# %%
from pathlib import Path
import duckdb
db = Path('../data/gold/prostate_journey.duckdb')
duckdb.connect(str(db), read_only=True).sql('select * from vw_treatment_gap_by_segment order by treatment_gap desc limit 20').df()
